# %%
import torch 
import numpy as np

# %%
x = [[1,2],[3,4]] 
print(type(x))
# Out:
# <class 'list'>

# %%
x_tensor = torch.tensor(x) 
print(x_tensor) 
print(type(x_tensor))
# Out:
# tensor([[1, 2],
#         [3, 4]])
# <class 'torch.Tensor'>

# %%
x_np = np.array(x) 
print(x_np) 
print(type(x_np))
# Out:
# [[1 2]
#  [3 4]]
# <class 'numpy.ndarray'>

# %%
x_tensor = torch.from_numpy(x_np)
print(x_tensor) 
print(type(x_tensor))
# Out:
# tensor([[1, 2],
#         [3, 4]])
# <class 'torch.Tensor'>

# %%
x_ones = torch.ones_like(x_tensor) 
print(x_ones)
# Out:
# tensor([[1, 1],
#         [1, 1]])

# %%
x_rand = torch.rand_like(x_tensor, dtype= torch.float) 
print(x_rand)
# Out:
# tensor([[0.4635, 0.5580],
#         [0.2927, 0.1521]])

# %%
shape = (2,3)
rand_tensor = torch.rand(shape) 
ones_tensor = torch.ones(shape) 
zeros_tensor = torch.zeros(shape) 

rand_tensor, ones_tensor, zeros_tensor
# Out:
# (tensor([[0.8480, 0.1013, 0.9766],
#          [0.2394, 0.5290, 0.1497]]),
#  tensor([[1., 1., 1.],
#          [1., 1., 1.]]),
#  tensor([[0., 0., 0.],
#          [0., 0., 0.]]))

# %%
# Attributes of tensors 

z_tensor = torch.rand(3,4) 
print(f'shape of tensor: {z_tensor.shape}') 
print(f"Datatype of tensor: {z_tensor.dtype}") 
print(f"Device tensor is stored on: {z_tensor.device}")
# Out:
# shape of tensor: torch.Size([3, 4])
# Datatype of tensor: torch.float32
# Device tensor is stored on: cpu

# %%
torch.cuda.is_available()
# Out:
# True

# %%
print(z_tensor)
# Out:
# tensor([[0.2726, 0.2139, 0.2955, 0.7869],
#         [0.4614, 0.5389, 0.4067, 0.8618],
#         [0.4000, 0.4552, 0.6146, 0.8558]])

# %%
# operations on tensors 
print("First row:",z_tensor[0]) 
print('First column:', z_tensor[:,0]) 
print('Last column:', z_tensor[:,-1]) 
z_tensor[:,1] = 0 
print(z_tensor)
# Out:
# First row: tensor([0.2726, 0.2139, 0.2955, 0.7869])
# First column: tensor([0.2726, 0.4614, 0.4000])
# Last column: tensor([0.7869, 0.8618, 0.8558])
# tensor([[0.2726, 0.0000, 0.2955, 0.7869],
#         [0.4614, 0.0000, 0.4067, 0.8618],
#         [0.4000, 0.0000, 0.6146, 0.8558]])

# %%
z_concat_col = torch.cat([z_tensor, z_tensor, z_tensor], dim= 1) 
print(z_concat_col)
# Out:
# tensor([[0.2726, 0.0000, 0.2955, 0.7869, 0.2726, 0.0000, 0.2955, 0.7869, 0.2726,
#          0.0000, 0.2955, 0.7869],
#         [0.4614, 0.0000, 0.4067, 0.8618, 0.4614, 0.0000, 0.4067, 0.8618, 0.4614,
#          0.0000, 0.4067, 0.8618],
#         [0.4000, 0.0000, 0.6146, 0.8558, 0.4000, 0.0000, 0.6146, 0.8558, 0.4000,
#          0.0000, 0.6146, 0.8558]])

# %%
z_concat_rows = torch.cat([z_tensor, z_tensor, z_tensor], dim= 0)
print(z_concat_rows)
# Out:
# tensor([[0.2726, 0.0000, 0.2955, 0.7869],
#         [0.4614, 0.0000, 0.4067, 0.8618],
#         [0.4000, 0.0000, 0.6146, 0.8558],
#         [0.2726, 0.0000, 0.2955, 0.7869],
#         [0.4614, 0.0000, 0.4067, 0.8618],
#         [0.4000, 0.0000, 0.6146, 0.8558],
#         [0.2726, 0.0000, 0.2955, 0.7869],
#         [0.4614, 0.0000, 0.4067, 0.8618],
#         [0.4000, 0.0000, 0.6146, 0.8558]])

# %%
# Matrix Multiplication 
y1 = z_tensor @ z_tensor.T 
print(y1)
y2 = z_tensor.matmul(z_tensor.T) 
print(y2) 

y3 = torch.rand_like(y1) 
torch.matmul(z_tensor, z_tensor.T, out= y3) 

print(y1) 
print(y2) 
print(y3)
# Out:
# tensor([[0.7809, 0.9241, 0.9641],
#         [0.9241, 1.1209, 1.1720],
#         [0.9641, 1.1720, 1.2700]])
# tensor([[0.7809, 0.9241, 0.9641],
#         [0.9241, 1.1209, 1.1720],
#         [0.9641, 1.1720, 1.2700]])
# tensor([[0.7809, 0.9241, 0.9641],
#         [0.9241, 1.1209, 1.1720],
#         [0.9641, 1.1720, 1.2700]])
# tensor([[0.7809, 0.9241, 0.9641],
#         [0.9241, 1.1209, 1.1720],
#         [0.9641, 1.1720, 1.2700]])
# tensor([[0.7809, 0.9241, 0.9641],
#         [0.9241, 1.1209, 1.1720],
#         [0.9641, 1.1720, 1.2700]])

# %%
# ElementWise Product 
t1 = z_tensor * z_tensor
t2 = z_tensor.mul(z_tensor) 

t3 = torch.rand_like(t1) 
torch.mul(z_tensor, z_tensor, out=t3) 

print(t1)
print(t2)
print(t3)
# Out:
# tensor([[0.0743, 0.0000, 0.0873, 0.6192],
#         [0.2128, 0.0000, 0.1654, 0.7427],
#         [0.1600, 0.0000, 0.3777, 0.7323]])
# tensor([[0.0743, 0.0000, 0.0873, 0.6192],
#         [0.2128, 0.0000, 0.1654, 0.7427],
#         [0.1600, 0.0000, 0.3777, 0.7323]])
# tensor([[0.0743, 0.0000, 0.0873, 0.6192],
#         [0.2128, 0.0000, 0.1654, 0.7427],
#         [0.1600, 0.0000, 0.3777, 0.7323]])

# %%
agg = z_tensor.sum() 
agg_item = agg.item() # converts 1x1 tensor to numeric value
print(agg,agg_item, type(agg_item), sep= '\n')
# Out:
# tensor(4.9552)
# 4.955198764801025
# <class 'float'>

# %%
z_tensor.add_(3)
# Out:
# tensor([[3.2726, 3.0000, 3.2955, 3.7869],
#         [3.4614, 3.0000, 3.4067, 3.8618],
#         [3.4000, 3.0000, 3.6146, 3.8558]])

# %%
# MNIST Dataset
import torch 
from torch.utils.data import Dataset 
from torchvision import datasets 
from torchvision.transforms import ToTensor 
import matplotlib.pyplot as plt 


training_data = datasets.FashionMNIST(
    root="data", # Download data in folder data 
    train=True, # train = True means that you are downloading the training data 
    download=True, # if the data is not there download it
    transform=ToTensor() # transform it to pytorch tensors 
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False, # Downloading the test_data 
    download=True,
    transform=ToTensor()
)

# %%
train_features, train_labels = training_data[0] 
print(f'Frature shape: {train_features.size()}')
# Out:
# Frature shape: torch.Size([1, 28, 28])

# %%
train_features, train_labels = next(iter(training_data)) 

img = train_features[0].squeeze() 
plt.imshow(img, cmap='grey') 
plt.show() 
print(f'label: {train_labels}')
# Out:
# label: 9

# %%
# What if the data is not available
# we need to create custum data set 
import os 
import pandas as pd 
from torchvision.io import decode_image

class CustomImageDataset(Dataset) : 
    def __init__ (self, annotations_file, img_dir, transform = None, target_transform=None):
        '''
        annotations_file is the file where the we have the relative paths and the labels 
        img_dir is the absloute path 
        '''
        self.img_labels = pd.read_csv(annotations_file) 
        self.img_dir = img_dir 
        self.transform = transform
        self.target_transform = target_transform

    def __len__ (self) : 
        return len(self.img_labels) 

    def __getitem__ (self, idx): 
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx,0]) 
        image = decode_image(img_path) 
        label = self.img_labels.iloc[idx,1] 
        if self.transform: 
            image = self.transform(image) 
        if self.target_transform:
            label = self.target_transform(label) 

        return image, label

# %%
import os 
import torch 
from torch import nn

# %%
device = "cuda" if torch.cuda.is_available() else "cpu" 
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class NeuralNetwork(nn.Module): 
    def __init__(self):
        super(NeuralNetwork, self).__init__() 
        self.flatten = nn.Flatten() 
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(), 
            nn.Linear(512, 10) 
        ) 

    def forward(self, x): 
        x = self.flatten(x) 
        logits = self.linear_relu_stack(x) 
        return logits

# %%
model = NeuralNetwork().to(device) 
print(model)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
x = torch.rand(1,28,28, device = device) 
logits = model(x) 
print(logits)
# Out:
# tensor([[-0.0487, -0.0752, -0.0214,  0.0283, -0.0435, -0.0479,  0.0332,  0.0473,
#          -0.1355,  0.1712]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
pred_prob = nn.Softmax(dim=1)(logits) 
print(pred_prob) 
y_pred = pred_prob.argmax(1) 
print(f"Predicted class: {y_pred}")
# Out:
# tensor([[0.0958, 0.0933, 0.0985, 0.1035, 0.0963, 0.0959, 0.1040, 0.1055, 0.0878,
#          0.1194]], device='cuda:0', grad_fn=<SoftmaxBackward0>)
# Predicted class: tensor([9], device='cuda:0')

# %%
flatten = nn.Flatten() 
flat_image = flatten(x) 
print(flat_image.size())
# Out:
# torch.Size([1, 784])

# %%
layer1 = nn.Linear(in_features= 28*28, out_features= 20).to(device) 
hidden1 = layer1(flat_image) 
print(hidden1)
# Out:
# tensor([[ 0.1861,  0.0863, -0.4806,  0.1147,  0.1561,  0.1427,  0.3777, -0.7052,
#          -0.1514,  0.0120, -0.0198,  0.0958,  0.0511, -0.2717,  0.2692, -0.1246,
#           0.0455, -0.3801, -0.0374, -0.8693]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
z = nn.ReLU()(hidden1) 
print(z)
# Out:
# tensor([[0.1861, 0.0863, 0.0000, 0.1147, 0.1561, 0.1427, 0.3777, 0.0000, 0.0000,
#          0.0120, 0.0000, 0.0958, 0.0511, 0.0000, 0.2692, 0.0000, 0.0455, 0.0000,
#          0.0000, 0.0000]], device='cuda:0', grad_fn=<ReluBackward0>)

# %%
# Autometic Differentiation 
x = torch.ones(5) # input tensor 
y = torch.zeros(3)  # expected output 

w = torch.randn(5,3, requires_grad= True)
b = torch.rand(3, requires_grad = True) 

z = torch.matmul(x,w) + b 
loss = torch.nn.functional.binary_cross_entropy_with_logits(z, y)

# %%
print(f"Gradient function for z = {z.grad_fn}") 
print(f"Gradient function for loss = {loss.grad_fn}")
# Out:
# Gradient function for z = <AddBackward0 object at 0x786461561d80>
# Gradient function for loss = <BinaryCrossEntropyWithLogitsBackward0 object at 0x786461560130>

# %%
print(w,b)
# Out:
# tensor([[ 1.2909,  0.2216, -0.9017],
#         [ 0.1064,  0.1263,  1.1869],
#         [-1.6347,  1.4569,  1.7179],
#         [-0.5574,  1.0212, -0.2248],
#         [ 1.8561,  2.3231, -0.7482]], requires_grad=True) tensor([0.8849, 0.8732, 0.1852], requires_grad=True)

# %%
loss.backward()
print(w.grad, b.grad)
# Out:
# tensor([[0.2917, 0.3325, 0.2571],
#         [0.2917, 0.3325, 0.2571],
#         [0.2917, 0.3325, 0.2571],
#         [0.2917, 0.3325, 0.2571],
#         [0.2917, 0.3325, 0.2571]]) tensor([0.2917, 0.3325, 0.2571])

# %%
z = torch.matmul(x,w) + b 
print(z.requires_grad)
# Out:
# True

# %%
with torch.no_grad():
    z = torch.matmul(x, w) + b
print(z.requires_grad)
# Out:
# False

# %%
z = torch.matmul(x, w) + b 
z_det = z.detach() 
print(z_det.requires_grad)
# Out:
# False

# %%
print(z.requires_grad)
# Out:
# True
